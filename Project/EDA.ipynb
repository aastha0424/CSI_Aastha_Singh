# %% [markdown]
# # 📊 Exploratory Data Analysis (EDA)
# **Objective**: To understand the structure, distribution, and relationships within the student performance dataset (`student-por.csv`) before applying machine learning models.

# %% [markdown]
# ### 📦 Dataset Overview
# 1. Source: Student Performance Dataset on Kaggle
# 2. File Analyzed: student-por.csv
# 3. Rows: 649 students
# 4. Columns: 33 features (demographic, social, academic)

# %% [markdown]
# ### 1️⃣ Data Loading & Initial Glance

# %%
import pandas as pd

df = pd.read_csv("student-por.csv")
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %% [markdown]
# -> Key Columns:
# 1. Demographics: sex, age, address, famsize, Pstatus
# 2. Parental Info: Medu, Fedu, Mjob, Fjob
# 3. Study Info: studytime, failures, schoolsup, paid
# 4. Grades: G1, G2, G3 (1st, 2nd, final period grades)

# %% [markdown]
# ### 2️⃣ Data Info & Missing Values

# %%
df.info()
df.isnull().sum()
df.describe()
df.describe(include='all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      649 non-null    object
#  1   sex         649 non-null    object
#  2   age         649 non-null    int64
#  3   address     649 non-null    object
#  4   famsize     649 non-null    object
#  5   Pstatus     649 non-null    object
#  6   Medu        649 non-null    int64
#  7   Fedu        649 non-null    int64
#  8   Mjob        649 non-null    object
#  9   Fjob        649 non-null    object
#  10  reason      649 non-null    object
#  11  guardian    649 non-null    object
#  12  traveltime  649 non-null    int64
#  13  studytime   649 non-null    int64
#  14  failures    649 non-null    int64
#  15  schoolsup   649 non-null    object
#  16  famsup      649 non-null    object
#  17  paid        649 non-null    object
#  18  activities  649 non-null    object
# ...

# %% [markdown]
# Findings:
#
# ✅ No missing values
#
# ✅ All data types are correctly inferred
#
# ℹ️ Many categorical variables need encoding for analysis

# %% [markdown]
# ### 3️⃣ Data Distributions

# %% [markdown]
# ##### a. Numerical Features

# %%
import matplotlib.pyplot as plt
import seaborn as sns

numeric_cols = df.select_dtypes(include='number').columns
df[numeric_cols].hist(figsize=(12, 8), bins=20, color='skyblue')
plt.tight_layout()

# %% [markdown]
# ### 🔍 Key Insights from Numeric Feature Distributions
#
# - **Age**: Most students are 15–17 years old.
# - **Parental Education**: Majority of students' parents have mid-to-high education levels (`Medu`, `Fedu` = 2–4).
# - **Travel Time**: Most students live close to school (value = 1).
#
# - **Study Time**: Concentrated around 1–2 hours/day.
# - **Failures**: Most students have no past failures (value = 0).
# - **Absences**: Right-skewed — most students have low absences, a few with >30 indicate outliers.
# - **Grades (G1, G2, G3)**: Roughly normal distribution with a peak between 10–15.
#
# - **Family Relationship (`famrel`)**: Rated positively (4–5).
# - **Free Time / Going Out**: Mostly moderate levels (3–4).
# - **Health**: Most rate health as good (4–5).
#
# - **Alcohol Use**:
#   - **Dalc (Weekdays)**: Very low for most.
#   - **Walc (Weekends)**: Slightly higher but still moderate.
#
# 📌 **Summary**:
# - Distributions are mostly clean and interpretable.
# - Strong academic indicators: `G1`, `G2`, `studytime`, `failures`.
# - Social behavior and absences may influence grades in non-linear ways.

# %% [markdown]
# ##### b. Categorical Features

# %%
import pandas as pd
import warnings
# Load the dataset (adjust path if needed)
df = pd.read_csv("student-por.csv")
# Suppress future warnings
warnings.filterwarnings("ignore", category=FutureWarning)
import seaborn as sns
import matplotlib.pyplot as plt

categorical_cols = df.select_dtypes(include='object').columns
n_cols = 3  # number of plots per row
n_rows = (len(categorical_cols) + n_cols - 1) // n_cols  # calculate rows needed

plt.figure(figsize=(n_cols * 5, n_rows * 4))  # adjust size as needed

for idx, col in enumerate(categorical_cols, 1):
    plt.subplot(n_rows, n_cols, idx)
    sns.countplot(x=col, data=df, palette="pastel")
    plt.xticks(rotation=45)
    plt.title(f"Distribution of {col}")
    plt.tight_layout()

plt.suptitle("📊 Categorical Feature Distributions", fontsize=16, y=1.02)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\2004a\AppData\Local\Temp\ipykernel_16740\4233884050.py:24: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\2004a\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ### 🧠 Key Insights from Categorical Feature Distributions
#
# This section summarizes the insights obtained by analyzing the distribution of all categorical variables in the dataset.
#
# ---
#
# #### 🏫 School & Demographics
# - **School**: Majority of students are from **GP**; fewer from **MS**.
# - **Sex**: Slightly more **female** students than **male**.
# - **Address**: Most students live in **urban areas**.
# - **Family Size**: More students belong to **larger families** (≥3 members).
# - **Parent Status (Pstatus)**: Most students report that their **parents live together**.
# - **Guardian**: Most students live with their **mother**, followed by **father** and **others**.
#
# ---
#
# #### 👨‍👩‍👧 Parental Occupation
# - **Mother's Job (Mjob)**: Commonly listed as **at_home**, **health**, **services**, or **teacher**.
# - **Father's Job (Fjob)**: Mostly **other**, **services**, or **teacher**.
#
# ---
#
# #### 📚 Academic Support & Activities
# - **School Support (schoolsup)**: Very few students receive **school-provided support**.
# - **Family Support (famsup)**: Majority of students report **receiving family support**.
# - **Paid Classes (paid)**: A minority of students take **extra paid classes**.
# - **Extra-curricular Activities**: Fairly balanced; slightly more students **participate** than not.
# - **Nursery Attendance**: Most students **attended nursery school**.
# - **Wants Higher Education**: Strong preference toward pursuing **higher studies**.
#
# ---
#
# #### 🌐 Lifestyle & Technology
# - **Internet Access**: Most students have **internet at home**.
# - **Romantic Relationships**: A smaller proportion of students are in a **romantic relationship**.
#
# ---
#
# #### 🏠 Reason for School Selection
# - **Reason**: Most students chose their school for the **course**, followed by **home proximity** and **reputation**.
#
# ---
#
# #### ✅ Summary
#
# - Students are generally **motivated** and supported by families to pursue education.
# - Most live in **urban areas** and have **internet access**, which is advantageous for learning.
# - **Parental involvement and background** vary but are mostly positive.
# - There's an opportunity to improve academic support through **increased school-based or paid support programs**.
#
# These insights are valuable for understanding the background of students and can influence how features are selected or encoded in modeling.

# %% [markdown]
# ### 4️⃣ Outlier Detection

# %%
for col in ['age', 'failures', 'absences', 'G1', 'G2', 'G3']:
    sns.boxplot(y=df[col])
    plt.title(f"Boxplot of {col}")
    plt.show()

# %% [markdown]
# ### 📌 Insights on Outlier Detection
# - **Absences**:
#   - The `absences` feature is **right-skewed** with a large number of students having **0–10 absences**.
#   - There are multiple **outliers with more than 30 absences**, which may indicate **chronic absenteeism** and could negatively impact performance.
#
# - **Failures & G3 (Final Grade)**:
#   - Both `failures` and `G3` show **significant clustering near 0**.
#   - This indicates that a subset of students are **failing severely**, receiving the lowest possible scores.
#   - These features may introduce **non-linear effects** or require **special handling** during modeling (e.g., separating failing students as a class).

# %% [markdown]
# ### 5️⃣ Correlation Analysis

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(df[numeric_cols].corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# ### 🔥 Correlation Heatmap Insights
#
# The correlation matrix provides important insights into how various numerical features are related to each other and to the final grade (`G3`):
#
# ---
#
# #### 🎯 Strongly Correlated with `G3` (Final Grade)
# - **G1 (First Period Grade)**: `0.83`
# - **G2 (Second Period Grade)**: `0.92`
#
# 📌 These are **strong positive correlations**, indicating that previous academic performance is a **very strong predictor** of final grades.
#
# ---
#
# #### 🔻 Negatively Correlated with `G3`
# - **Failures**: `-0.39` → Students with more past class failures tend to perform worse.
# - **Absences**: `-0.13` → Higher absenteeism is weakly correlated with lower performance.
# - **Dalc (Workday alcohol use)**: `-0.18` → Slight negative correlation; higher alcohol consumption may be detrimental.
#
# ---
#
# #### ➕ Weak to Moderate Positive Correlations
# - **Study Time**: `0.25` → Slightly positive impact on grades.
# - **Mother’s Education (Medu)**: `0.24`
# - **Father’s Education (Fedu)**: `0.21`
#
# These features suggest that **parental education and time spent studying** have a **moderate influence** on student success.
#
# ---
#
# #### 🧊 Weak or No Correlation
# - Features like `goout`, `health`, `freetime`, `famrel` show **little to no correlation** with `G3`.
# - This suggests these lifestyle or social factors may not significantly impact academic outcomes directly.
#
# ---
#
# ### ✅ Summary
#
# - Prior grades (`G1`, `G2`) are the **strongest predictors** of `G3`.
# - Behavioral and demographic features have **moderate to weak** influence.
# - Features like `failures`, `absences`, and `Dalc` may be important for identifying at-risk students.
#
# This analysis supports selecting `G1`, `G2`, `studytime`, `failures`, and `Medu/Fedu` as important features for regression modeling.

# %% [markdown]
# ### 6️⃣ Relationship Exploration

# %% [markdown]
# ##### a. Final Grade (G3) vs Studytime

# %%
sns.boxplot(x='studytime', y='G3', data=df)
plt.title("Study Time vs Final Grade")
plt.show()

# %% [markdown]
# ##### 📚 Study Time vs Final Grade
#
# - Students with **higher study time** tend to have **higher final grades**.
# - **Low studytime (1)** group shows lower median and more failing grades.
# - **Studytime = 3 or 4** groups perform better and more consistently.
# - Overall, `studytime` is a useful feature for predicting student performance.

# %% [markdown]
# ##### b. Parental Education vs Final Grade

# %%
sns.boxplot(x='Medu', y='G3', data=df)
plt.title("Mother's Education vs Final Grade")
plt.show()

sns.boxplot(x='Fedu', y='G3', data=df)
plt.title("Father's Education vs Final Grade")
plt.show()

# %% [markdown]
# ##### 🧑‍🎓 Parental Education vs Final Grade
#
# The boxplots above show how the final grade (`G3`) varies based on parents' education levels.
#
# ---
#
# ##### 📘 Mother's Education (`Medu`)
# - As the **education level of the mother increases**, the **median final grade also increases**.
# - Students whose mothers have higher education (level 4) show:
#   - Higher median performance
#   - Slightly wider grade range, suggesting more variation but higher potential
# - Students with no maternal education (`Medu = 0`) have lower and more consistent (narrow) grade outcomes.
#
# ---
#
# ##### 📗 Father's Education (`Fedu`)
# - A similar positive trend is observed:
#   - **Higher `Fedu` is associated with better performance**.
#   - Students with fathers at education level 4 have among the **highest median G3 scores**.
# - The effect is **less pronounced** than mother's education but still noticeable.
#
# ---
#
# ##### ✅ Conclusion
# - **Parental education**, especially the **mother’s**, is positively associated with academic performance.
# - These features are valuable for inclusion in predictive models.

# %% [markdown]
# ##### c. Internet Access vs G3

# %%
sns.boxplot(x='internet', y='G3', data=df)
plt.title("Internet Access vs Final Grade")
plt.show()

# %% [markdown]
# #### 🌐 Internet Access vs Final Grade (G3)
#
# This boxplot compares students with and without internet access at home and their final grades (`G3`).
#
# ---
#
# ##### 🔎 Observations:
# - Students **with internet access** have a **slightly higher median** `G3` than those without.
# - The **distribution is wider** for students with internet, suggesting more variation in performance.
# - Both groups contain outliers, including a few students with very low final grades (`G3 ≈ 0`).
# - While the difference isn't drastic, the presence of internet may offer **educational resources** that support performance.
#
# ---
#
# ##### ✅ Insight:
# - **Internet access** may be a **mildly positive influence** on academic performance.
# - It could serve as a **supportive feature**, especially in combination with other variables like `studytime` and `parental education`.

# %% [markdown]
# ### 🔍 Summary of Findings

# %% [markdown]
# ## 📊 Exploratory Data Analysis (EDA) – Summary of Key Findings
#
# This section provides a comprehensive overview of the insights extracted from the dataset during the EDA process. It includes distributions, relationships, and potential influences on student performance.
#
# ---
#
# ### 🎯 Target Variable: `G3` (Final Grade)
# - The final grade is **normally distributed**, mostly between **8 and 14**.
# - A few students score extremely low (0–2), likely indicating failures.
#
# ---
#
# ### 🧮 Numerical Feature Insights (Histograms + Boxplots)
# - **Absences**:
#   - Right-skewed with **outliers beyond 30 days**.
#   - Chronic absenteeism may impact grades.
# - **Failures**:
#   - Heavy clustering at 0, but students with 3+ failures often perform very poorly.
# - **G1 & G2**:
#   - Both are **strongly correlated with G3**.
#   - G2 (`r = 0.92`) and G1 (`r = 0.83`) are top predictors.
# - **Studytime**:
#   - Positive impact: more study time generally results in higher final grades.
# - **Dalc/Walc (Alcohol Use)**:
#   - Daily alcohol consumption shows a **negative correlation** with G3.
# - **Health, Freetime, Goout**:
#   - These lifestyle features show **little to no correlation** with performance.
#
# ---
#
# ### 🔡 Categorical Feature Distributions (Grouped Countplots)
# - Most students:
#   - Belong to **school GP**
#   - Live in **urban areas**
#   - Have **internet access**
#   - Plan to pursue **higher education**
#   - Receive **family support**, but very few receive **school support**
# - **Guardian** is most often the **mother**.
# - **Mother’s job** is frequently "at_home" or "services".
#
# ---
#
# ### 📈 Correlation Heatmap (Pearson Coefficients)
# - Top positive correlations with `G3`:
#   - `G2` → 0.92
#   - `G1` → 0.83
#   - `Studytime` → 0.25
#   - `Medu` (Mother's education) → 0.24
#   - `Fedu` (Father's education) → 0.21
# - Top negative correlations:
#   - `Failures` → -0.39
#   - `Dalc` → -0.18
#   - `Absences` → -0.13
#
# ---
#
# ### 📊 Boxplots: Key Relationships
# - **Studytime vs G3**: Higher study time leads to higher grades.
# - **Medu/Fedu vs G3**: Higher parental education → better performance.
# - **Internet Access vs G3**: Students with internet show slightly better grades.
# - **Failures vs G3**: Strong negative impact on grades.
# - **Absences vs G3**: More absences → lower performance.
#
# ---
#
# ### 📌 Overall Insights
# - **G1**, **G2**, **studytime**, **failures**, and **parental education** are most important features.
# - **Absences** and **alcohol use** are useful for identifying **at-risk students**.
# - Some social/lifestyle features (e.g., health, goout, freetime) show **limited predictive value**.
#
# ---
#
# ### 🖼️ Visuals Used in EDA
# - 📊 Histograms of all numerical features
# - 📦 Boxplots for feature vs G3 comparisons
# - 🔥 Correlation heatmap
# - 📉 Countplots of all categorical variables (in one grid)
